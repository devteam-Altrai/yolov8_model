# %%
# %pip install ultralytics opencv-python torch torchvision torchaudio numpy pandas matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import torch
import numpy as np
from ultralytics import YOLO
from pathlib import Path

# %%
# Change this to your dataset path
dataset_path = r"C:/Users/YourName/Documents/yolov11"

train_images = os.path.join(dataset_path, "train/images")
val_images = os.path.join(dataset_path, "val/images")

# %%
from pathlib import Path

yaml_path = Path("C:/Users/Gowtham Singh Saud/Documents/yolov11/data.yaml")

yaml_content = """
train: ../train/images
val: ../valid/images
test: ../test/images

nc: 3
names: ['grazing', 'moving', 'sitting','standing]

roboflow:
  workspace: cattle-erxro
  project: cattle-wjqes
  version: 1
  license: CC BY 4.0
  url: https://universe.roboflow.com/cattle-erxro/cattle-wjqes/dataset/1
"""

yaml_path.write_text(yaml_content.strip())
print("✅ data.yaml written successfully at:", yaml_path)
# Out:
# ✅ data.yaml written successfully at: C:\Users\Gowtham Singh Saud\Documents\yolov11\data.yaml

# %%
import cv2
import matplotlib.pyplot as plt
import random
from pathlib import Path

# Load and visualize a sample image with its label
def show_image_with_boxes(image_path, label_path, class_names):
    image = cv2.imread(str(image_path))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    height, width, _ = image.shape

    with open(label_path, 'r') as f:
        for line in f.readlines():
            cls, x_center, y_center, w, h = map(float, line.strip().split())
            x1 = int((x_center - w / 2) * width)
            y1 = int((y_center - h / 2) * height)
            x2 = int((x_center + w / 2) * width)
            y2 = int((y_center + h / 2) * height)
            cv2.rectangle(image, (x1, y1), (x2, y2), (255, 0, 0), 2)
            cv2.putText(image, class_names[int(cls)], (x1, y1 - 10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    plt.imshow(image)
    plt.axis("off")
    plt.show()

# ✅ Define dataset base path (Change this to your actual root dataset path)
dataset_path = Path("C:/Users/Gowtham Singh Saud/Documents/yolov11/train")

# ✅ Define image and label directories
img_dir = dataset_path / "images"
label_dir = dataset_path / "labels"

# ✅ List image and label files
image_files = list(img_dir.glob("*.jpg"))
label_files = list(label_dir.glob("*.txt"))

# ✅ Define class names
class_names = ['standing'] 
class_names = ['sitting'] 
class_names = ['grazing ']
Class_names = ['moving'] # Adjust class names as per your dataset

# ✅ Visualize a random sample
if image_files and label_files:
    sample_idx = random.randint(0, len(image_files) - 1)
    show_image_with_boxes(image_files[sample_idx], label_files[sample_idx], class_names)
else:
    print("No image or label files found in the directory.")
